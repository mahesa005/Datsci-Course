# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import statsmodels.api as sm

# %%
data = pd.read_csv('1.01.+Simple+linear+regression.csv')
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
data.describe()
# Out:
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %% [markdown]
# Show scatter plot

# %%
# Formula: y = b0 + b1*x1
y = data['GPA']
x1 = data['SAT']
plt.scatter(x1, y)
plt.xlabel("SAT", fontsize=16)
plt.ylabel("GPA", fontsize=16)
plt.show()

# %% [markdown]
# The scatter plot indicates a strong linear relationship between the two,
# Lanjut, The regression itself

# %%
x = sm.add_constant(x1) # basically adds another column in front of every x1 data with a 1. jadi misal tadi data x1 = [23], [256], .. jadinya x = [1,23], [1,256],..
results = sm.OLS(y,x).fit() # ini ngitung linear regression nya, ngegunain rumus di tubes 1 algeo
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     56.05
# Date:                Thu, 03 Jul 2025   Prob (F-statistic):           7.20e-11
# Time:                        02:18:57   Log-Likelihood:                 12.672
# No. Observations:                  84   AIC:                            -21.34
# Df Residuals:                      82   BIC:                            -16.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2750      0.409      0.673      0.503      -0.538       1.088
# ...

# %%
# Show hasil regression linenya di scatter plotnya
# hasil dari results summary: y = 0.2750 + 0.0017*x1
plt.scatter(x1, y)
yhat = 0.2750 + 0.0017*x1
plt.plot(x1, yhat, lw=4, c='orange', label='regression line')
plt.xlabel("SAT", fontsize=16)
plt.ylabel("GPA", fontsize=16)
plt.show()
